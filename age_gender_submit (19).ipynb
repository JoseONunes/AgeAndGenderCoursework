# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow

dataset_path = "/content/drive/MyDrive/train_val" #for google colab
#dataset_path = "train_val" #for local running

image_files = [f for f in os.listdir(dataset_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

random.shuffle(image_files)
selected_images = image_files[:20]

def extract_label(filename):
    try:
        name = filename.split('_')
        age = int(name[0])
        gender = "Male" if name[1] == "0" else "Female"  # Second part is gender (0 = Male, 1 = Female)
        return age, gender
    except:
        return None, None  # Handle unexpected filename formats

# Plot 20 images in a 4x5 grid
fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for i, ax in enumerate(axes.flat):
    if i < len(selected_images):
        img_path = os.path.join(dataset_path, selected_images[i])
        img = cv2.imread(img_path)  # Read image
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

        # Extract labels from filename
        age, gender = extract_label(selected_images[i])
        label = f"Age: {age}, Gender: {gender}" if age is not None else "Unknown"

        # Display image
        ax.imshow(img)
        ax.set_title(label, fontsize=10)
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
folder_train_val = "/content/drive/MyDrive/train_val" #for google colab
#folder_train_val = "train_val" #for local running

all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
    print('load all image data, age and gender labels...')
    images = []
    age_labels = []
    gender_labels = []
    for current_file_name in filenames:
        img = cv2.imread(os.path.join(dataset_path, current_file_name))
        img = img / 255.0  # Normalize pixel values
        labels = current_file_name.split('_')
        age_label = int(labels[0])
        gender_label = int(labels[1])
        age_labels.append(age_label)
        gender_labels.append(gender_label)
        images.append(img)

# Convert to NumPy arrays
    images = np.array(images)
    age_labels = np.array(age_labels)
    gender_labels = np.array(gender_labels)
    return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
######### Add your code for data augmentation here #########
#
inputs = tensorflow.keras.Input(shape=(128, 128, 3))
# Apply data augmentation layers to the inputs
augmented = tensorflow.keras.layers.RandomFlip("horizontal")(inputs)
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
x = tensorflow.keras.layers.Conv2D(32, (3, 3), activation='relu')(augmented)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(128, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(256, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Flatten()(x)
x = tensorflow.keras.layers.Dense(256, activation='relu')(x)
x = tensorflow.keras.layers.Dropout(0.3)(x)

gender = tensorflow.keras.layers.Dense(1, activation='sigmoid', name='gender')(x)
age = tensorflow.keras.layers.Dense(1, activation='linear', name='age')(x)

modelA = tensorflow.keras.Model(inputs=inputs, outputs=[gender, age])

modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True,dpi=100)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_flip (RandomFlip)  │ (None, 128, 128, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 126, 126, 32)   │            896 │ random_flip[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 63, 63, 32)     │              0 │ conv2d[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 61, 61, 64)     │         18,496 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 30, 30, 64)     │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 28, 28, 128)    │         73,856 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 14, 14, 128)    │              0 │ conv2d_2[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 12, 12, 256)    │        295,168 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 6, 6, 256)      │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 9216)           │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │      2,359,552 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │            257 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            257 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,748,482 (10.48 MB)
#  Trainable params: 2,748,482 (10.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_gender_accuracy',patience=5,restore_best_weights=True,mode='max',verbose=1)

modelA.compile(
    optimizer=tensorflow.keras.optimizers.Adam(),
    loss={
        "gender": tensorflow.keras.losses.BinaryCrossentropy(),
        "age": tensorflow.keras.losses.MeanAbsoluteError(),
    },
    loss_weights = {"gender": 1.5, "age": 1.0},
    metrics={
        "gender": ["accuracy"],
        "age": ["mae"]
    }
)

historyA = modelA.fit(
    x=train_images,
    y={
        "gender": train_gender,
        "age": train_age
    },
    validation_data=(
        val_images,
        {
            "gender": val_gender,
            "age": val_age
        }
    ),
    epochs=30 ,
    batch_size=32,
    callbacks=[early_stopping]
)

import os

folder_models = "/content/drive/MyDrive/models/temp/"
if not os.path.exists(folder_models):
    os.makedirs(folder_models)

# Save the model only once using the correct absolute path
modelA.save(os.path.join(folder_models, 'age_gender_A.keras'))
print("Model saved successfully!")
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - age_loss: 17.7558 - age_mae: 17.7558 - gender_accuracy: 0.5101 - gender_loss: 0.9923 - loss: 19.2443 - val_age_loss: 15.3432 - val_age_mae: 15.3644 - val_gender_accuracy: 0.4570 - val_gender_loss: 0.7110 - val_loss: 16.4277
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 15.0784 - age_mae: 15.0784 - gender_accuracy: 0.5241 - gender_loss: 0.7790 - loss: 16.2469 - val_age_loss: 15.1531 - val_age_mae: 15.1643 - val_gender_accuracy: 0.5540 - val_gender_loss: 0.7286 - val_loss: 16.2615
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 13.9891 - age_mae: 13.9891 - gender_accuracy: 0.6331 - gender_loss: 0.6818 - loss: 15.0119 - val_age_loss: 13.7070 - val_age_mae: 13.7778 - val_gender_accuracy: 0.7400 - val_gender_loss: 0.5527 - val_loss: 14.5946
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 12.6052 - age_mae: 12.6052 - gender_accuracy: 0.6886 - gender_loss: 0.6012 - loss: 13.5069 - val_age_loss: 11.7505 - val_age_mae: 11.7308 - val_gender_accuracy: 0.7670 - val_gender_loss: 0.4869 - val_loss: 12.4536
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - age_loss: 12.2149 - age_mae: 12.2149 - gender_accuracy: 0.7469 - gender_loss: 0.5349 - loss: 13.0172 - val_age_loss: 11.4122 - val_age_mae: 11.4227 - val_gender_accuracy: 0.7800 - val_gender_loss: 0.4894 - val_loss: 12.1472
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - age_loss: 10.9133 - age_mae: 10.9133 - gender_accuracy: 0.7441 - gender_loss: 0.5176 - loss: 11.6897 - val_age_loss: 10.2257 - val_age_mae: 10.2406 - val_gender_accuracy: 0.7780 - val_gender_loss: 0.4868 - val_loss: 10.9662
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 10.4847 - age_mae: 10.4847 - gender_accuracy: 0.7527 - gender_loss: 0.5198 - loss: 11.2644 - val_age_loss: 9.7930 - val_age_mae: 9.7903 - val_gender_accuracy: 0.7910 - val_gender_loss: 0.4532 - val_loss: 10.4593
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - age_loss: 10.2597 - age_mae: 10.2597 - gender_accuracy: 0.7718 - gender_loss: 0.4766 - loss: 10.9746 - val_age_loss: 10.1912 - val_age_mae: 10.1744 - val_gender_accuracy: 0.7890 - val_gender_loss: 0.4761 - val_loss: 10.8879
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 9.7722 - age_mae: 9.7722 - gender_accuracy: 0.7790 - gender_loss: 0.4629 - loss: 10.4665 - val_age_loss: 10.0629 - val_age_mae: 10.0752 - val_gender_accuracy: 0.8110 - val_gender_loss: 0.4187 - val_loss: 10.6965
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 9.7116 - age_mae: 9.7116 - gender_accuracy: 0.7874 - gender_loss: 0.4666 - loss: 10.4115 - val_age_loss: 9.7890 - val_age_mae: 9.7608 - val_gender_accuracy: 0.7390 - val_gender_loss: 0.4667 - val_loss: 10.4467
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - age_loss: 9.3238 - age_mae: 9.3238 - gender_accuracy: 0.8092 - gender_loss: 0.4172 - loss: 9.9495 - val_age_loss: 8.9811 - val_age_mae: 8.9734 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.3953 - val_loss: 9.5580
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 8.5319 - age_mae: 8.5319 - gender_accuracy: 0.8104 - gender_loss: 0.4095 - loss: 9.1461 - val_age_loss: 8.4992 - val_age_mae: 8.4791 - val_gender_accuracy: 0.7610 - val_gender_loss: 0.4742 - val_loss: 9.1723
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 8.6257 - age_mae: 8.6257 - gender_accuracy: 0.8058 - gender_loss: 0.4088 - loss: 9.2389 - val_age_loss: 7.9686 - val_age_mae: 7.9557 - val_gender_accuracy: 0.8320 - val_gender_loss: 0.3728 - val_loss: 8.5086
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 8.2031 - age_mae: 8.2031 - gender_accuracy: 0.8240 - gender_loss: 0.3861 - loss: 8.7823 - val_age_loss: 8.1039 - val_age_mae: 8.0968 - val_gender_accuracy: 0.7990 - val_gender_loss: 0.4094 - val_loss: 8.6996
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - age_loss: 7.8992 - age_mae: 7.8992 - gender_accuracy: 0.8093 - gender_loss: 0.3851 - loss: 8.4768 - val_age_loss: 8.1759 - val_age_mae: 8.1574 - val_gender_accuracy: 0.8210 - val_gender_loss: 0.3746 - val_loss: 8.7099
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 7.8842 - age_mae: 7.8842 - gender_accuracy: 0.8334 - gender_loss: 0.3679 - loss: 8.4360 - val_age_loss: 8.0236 - val_age_mae: 7.9733 - val_gender_accuracy: 0.8420 - val_gender_loss: 0.3366 - val_loss: 8.4672
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 7.5425 - age_mae: 7.5425 - gender_accuracy: 0.8499 - gender_loss: 0.3387 - loss: 8.0505 - val_age_loss: 9.0372 - val_age_mae: 9.0296 - val_gender_accuracy: 0.8460 - val_gender_loss: 0.3276 - val_loss: 9.5138
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - age_loss: 7.1402 - age_mae: 7.1402 - gender_accuracy: 0.8391 - gender_loss: 0.3450 - loss: 7.6576 - val_age_loss: 7.5223 - val_age_mae: 7.5360 - val_gender_accuracy: 0.8370 - val_gender_loss: 0.3218 - val_loss: 8.0112
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 7.0446 - age_mae: 7.0446 - gender_accuracy: 0.8479 - gender_loss: 0.3360 - loss: 7.5486 - val_age_loss: 8.3223 - val_age_mae: 8.3019 - val_gender_accuracy: 0.8520 - val_gender_loss: 0.3298 - val_loss: 8.7882
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_loss: 7.0352 - age_mae: 7.0352 - gender_accuracy: 0.8493 - gender_loss: 0.3390 - loss: 7.5437 - val_age_loss: 7.6396 - val_age_mae: 7.6390 - val_gender_accuracy: 0.8310 - val_gender_loss: 0.3572 - val_loss: 8.1634
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 6.8286 - age_mae: 6.8286 - gender_accuracy: 0.8526 - gender_loss: 0.3177 - loss: 7.3051 - val_age_loss: 7.4521 - val_age_mae: 7.4452 - val_gender_accuracy: 0.8430 - val_gender_loss: 0.3226 - val_loss: 7.9218
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 6.6182 - age_mae: 6.6182 - gender_accuracy: 0.8512 - gender_loss: 0.3246 - loss: 7.1051 - val_age_loss: 7.3741 - val_age_mae: 7.3979 - val_gender_accuracy: 0.8530 - val_gender_loss: 0.3193 - val_loss: 7.8696
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - age_loss: 6.2587 - age_mae: 6.2587 - gender_accuracy: 0.8658 - gender_loss: 0.3227 - loss: 6.7428 - val_age_loss: 7.3233 - val_age_mae: 7.3518 - val_gender_accuracy: 0.8340 - val_gender_loss: 0.3649 - val_loss: 7.8828
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 6.2536 - age_mae: 6.2536 - gender_accuracy: 0.8584 - gender_loss: 0.3116 - loss: 6.7210 - val_age_loss: 7.5538 - val_age_mae: 7.5618 - val_gender_accuracy: 0.8550 - val_gender_loss: 0.3179 - val_loss: 8.0329
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 6.2954 - age_mae: 6.2954 - gender_accuracy: 0.8662 - gender_loss: 0.2828 - loss: 6.7196 - val_age_loss: 7.5261 - val_age_mae: 7.5336 - val_gender_accuracy: 0.8620 - val_gender_loss: 0.3210 - val_loss: 8.0021
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 5.9044 - age_mae: 5.9044 - gender_accuracy: 0.8697 - gender_loss: 0.2807 - loss: 6.3254 - val_age_loss: 7.6116 - val_age_mae: 7.6243 - val_gender_accuracy: 0.8620 - val_gender_loss: 0.3063 - val_loss: 8.0798
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - age_loss: 6.1050 - age_mae: 6.1050 - gender_accuracy: 0.8846 - gender_loss: 0.2591 - loss: 6.4937 - val_age_loss: 7.1229 - val_age_mae: 7.1701 - val_gender_accuracy: 0.8460 - val_gender_loss: 0.3220 - val_loss: 7.6422
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 5.8704 - age_mae: 5.8704 - gender_accuracy: 0.8903 - gender_loss: 0.2631 - loss: 6.2649 - val_age_loss: 7.3736 - val_age_mae: 7.4045 - val_gender_accuracy: 0.8630 - val_gender_loss: 0.3146 - val_loss: 7.8628
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 5.8273 - age_mae: 5.8273 - gender_accuracy: 0.8742 - gender_loss: 0.2704 - loss: 6.2329 - val_age_loss: 7.3591 - val_age_mae: 7.3635 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.3663 - val_loss: 7.9006
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 5.4958 - age_mae: 5.4958 - gender_accuracy: 0.8888 - gender_loss: 0.2445 - loss: 5.8626 - val_age_loss: 7.3184 - val_age_mae: 7.3369 - val_gender_accuracy: 0.8700 - val_gender_loss: 0.3038 - val_loss: 7.7828
# Restoring model weights from the end of the best epoch: 30.
# Model saved successfully!

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
gender_train_loss = historyA.history['gender_loss']
gender_val_loss = historyA.history['val_gender_loss']

gender_train_accuracy = historyA.history['gender_accuracy']
gender_val_accuracy = historyA.history['val_gender_accuracy']

age_train_loss = historyA.history['age_loss']
age_val_loss = historyA.history['val_age_loss']

age_train_accuracy = historyA.history['age_mae']
age_val_accuracy = historyA.history['val_age_mae']

epochs = range(len(gender_train_loss))


# Gender Loss
plt.subplot(2, 2, 1)
plt.plot(epochs, gender_train_loss, label='Train Loss')
plt.plot(epochs, gender_val_loss, label='Validation Loss')
plt.title('Gender Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gender Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, gender_train_accuracy, label='Train Accuracy')
plt.plot(epochs, gender_val_accuracy, label='Validation Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Age Loss
plt.subplot(2, 2, 3)
plt.plot(epochs, age_train_loss, label='Train Loss')
plt.plot(epochs, age_val_loss, label='Validation Loss')
plt.title('Age Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Age MAE
plt.subplot(2, 2, 4)
plt.plot(epochs, age_train_accuracy, label='Train MAE')
plt.plot(epochs, age_val_accuracy, label='Validation MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# MobileNetV2 with our specified input shape
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(128, 128, 3))


base_model.trainable = False


x = base_model(augmented)
x = GlobalAveragePooling2D()(x)

x = Dense(128, activation="relu")(x)
x = Dropout(0.3)(x)

#creating the branches for both estimaters
age_output = Dense(1, activation="linear", name="age")(x)
gender_output = Dense(1, activation="sigmoid", name="gender")(x) # Same activation functions as before



modelB = Model(inputs=inputs, outputs=[age_output, gender_output])

modelB.summary()
plot_model(modelB, to_file="modelB_architecture.png", show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_flip (RandomFlip)  │ (None, 128, 128, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mobilenetv2_1.00_128      │ (None, 4, 4, 1280)     │      2,257,984 │ random_flip[0][0]      │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ mobilenetv2_1.00_128[… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            129 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │            129 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,210 (9.24 MB)
#  Trainable params: 164,226 (641.51 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
import tensorflow as tf
import os
from tensorflow.keras.callbacks import EarlyStopping

# same compilation structure as before
modelB.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss={"age": "mean_absolute_error", "gender": "binary_crossentropy"},
    metrics={"age": "mae", "gender": "accuracy"}
)

early_stopping = EarlyStopping(monitor='val_gender_accuracy',patience=5,restore_best_weights=True,mode='max',verbose=1)

# Training, keeping the parameters the same as previous
historyB = modelB.fit(
    x=train_images,
    y={"age": train_age, "gender": train_gender},
    validation_data=(val_images, {"age": val_age, "gender": val_gender}),
    epochs=30,
    batch_size=32,
    callbacks=[early_stopping]
)

import os

folder_models = "/content/drive/MyDrive/models/temp/"
if not os.path.exists(folder_models):
    os.makedirs(folder_models)

# Save the model only once using the correct absolute path
modelB.save(os.path.join(folder_models, 'age_gender_B.keras'))
print("Model saved successfully!")
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - age_loss: 16.6002 - age_mae: 16.6002 - gender_accuracy: 0.6305 - gender_loss: 0.8401 - loss: 17.4403 - val_age_loss: 10.8700 - val_age_mae: 10.8335 - val_gender_accuracy: 0.7740 - val_gender_loss: 0.4857 - val_loss: 11.3064
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - age_loss: 10.5605 - age_mae: 10.5605 - gender_accuracy: 0.7545 - gender_loss: 0.5478 - loss: 11.1083 - val_age_loss: 10.1548 - val_age_mae: 10.1217 - val_gender_accuracy: 0.7890 - val_gender_loss: 0.4621 - val_loss: 10.5701
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - age_loss: 10.0376 - age_mae: 10.0376 - gender_accuracy: 0.7762 - gender_loss: 0.4981 - loss: 10.5357 - val_age_loss: 10.2211 - val_age_mae: 10.2115 - val_gender_accuracy: 0.8170 - val_gender_loss: 0.4306 - val_loss: 10.6336
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 9.9032 - age_mae: 9.9032 - gender_accuracy: 0.7788 - gender_loss: 0.4628 - loss: 10.3660 - val_age_loss: 9.4136 - val_age_mae: 9.3893 - val_gender_accuracy: 0.8240 - val_gender_loss: 0.3978 - val_loss: 9.7791
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - age_loss: 9.4155 - age_mae: 9.4155 - gender_accuracy: 0.8063 - gender_loss: 0.4356 - loss: 9.8511 - val_age_loss: 9.2140 - val_age_mae: 9.1849 - val_gender_accuracy: 0.8230 - val_gender_loss: 0.4055 - val_loss: 9.5824
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - age_loss: 9.0039 - age_mae: 9.0039 - gender_accuracy: 0.8163 - gender_loss: 0.4066 - loss: 9.4105 - val_age_loss: 9.2707 - val_age_mae: 9.2558 - val_gender_accuracy: 0.8090 - val_gender_loss: 0.4355 - val_loss: 9.6767
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_loss: 8.9376 - age_mae: 8.9376 - gender_accuracy: 0.8162 - gender_loss: 0.4032 - loss: 9.3407 - val_age_loss: 9.8408 - val_age_mae: 9.8024 - val_gender_accuracy: 0.8160 - val_gender_loss: 0.4175 - val_loss: 10.2070
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - age_loss: 8.8722 - age_mae: 8.8722 - gender_accuracy: 0.8210 - gender_loss: 0.4251 - loss: 9.2973 - val_age_loss: 9.0392 - val_age_mae: 9.0258 - val_gender_accuracy: 0.8300 - val_gender_loss: 0.3897 - val_loss: 9.4071
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - age_loss: 8.8620 - age_mae: 8.8620 - gender_accuracy: 0.8152 - gender_loss: 0.3959 - loss: 9.2579 - val_age_loss: 9.0649 - val_age_mae: 9.0804 - val_gender_accuracy: 0.8290 - val_gender_loss: 0.4040 - val_loss: 9.4726
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 8.5925 - age_mae: 8.5925 - gender_accuracy: 0.8301 - gender_loss: 0.3808 - loss: 8.9732 - val_age_loss: 8.9650 - val_age_mae: 8.9708 - val_gender_accuracy: 0.8160 - val_gender_loss: 0.4003 - val_loss: 9.3704
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 8.4600 - age_mae: 8.4600 - gender_accuracy: 0.8267 - gender_loss: 0.3919 - loss: 8.8518 - val_age_loss: 8.9558 - val_age_mae: 8.9566 - val_gender_accuracy: 0.8240 - val_gender_loss: 0.4246 - val_loss: 9.3662
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - age_loss: 8.5322 - age_mae: 8.5322 - gender_accuracy: 0.8176 - gender_loss: 0.3902 - loss: 8.9223 - val_age_loss: 9.0904 - val_age_mae: 9.1043 - val_gender_accuracy: 0.8430 - val_gender_loss: 0.3856 - val_loss: 9.4816
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 8.6736 - age_mae: 8.6736 - gender_accuracy: 0.8336 - gender_loss: 0.3963 - loss: 9.0700 - val_age_loss: 8.7516 - val_age_mae: 8.7736 - val_gender_accuracy: 0.8280 - val_gender_loss: 0.3884 - val_loss: 9.1554
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - age_loss: 8.1233 - age_mae: 8.1233 - gender_accuracy: 0.8326 - gender_loss: 0.3701 - loss: 8.4934 - val_age_loss: 8.8487 - val_age_mae: 8.8657 - val_gender_accuracy: 0.8180 - val_gender_loss: 0.4545 - val_loss: 9.3024
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 8.3540 - age_mae: 8.3540 - gender_accuracy: 0.8358 - gender_loss: 0.3778 - loss: 8.7318 - val_age_loss: 8.7423 - val_age_mae: 8.7447 - val_gender_accuracy: 0.8340 - val_gender_loss: 0.4048 - val_loss: 9.1371
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - age_loss: 8.2972 - age_mae: 8.2972 - gender_accuracy: 0.8398 - gender_loss: 0.3550 - loss: 8.6521 - val_age_loss: 8.8285 - val_age_mae: 8.8524 - val_gender_accuracy: 0.8350 - val_gender_loss: 0.3970 - val_loss: 9.2399
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - age_loss: 8.3031 - age_mae: 8.3031 - gender_accuracy: 0.8351 - gender_loss: 0.3767 - loss: 8.6797 - val_age_loss: 8.6803 - val_age_mae: 8.6933 - val_gender_accuracy: 0.8280 - val_gender_loss: 0.3784 - val_loss: 9.0656
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Model saved successfully!

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
gender_train_loss = historyB.history['gender_loss']
gender_val_loss = historyB.history['val_gender_loss']

gender_train_accuracy = historyB.history['gender_accuracy']
gender_val_accuracy = historyB.history['val_gender_accuracy']

age_train_loss = historyB.history['age_loss']
age_val_loss = historyB.history['val_age_loss']

age_train_accuracy = historyB.history['age_mae']
age_val_accuracy = historyB.history['val_age_mae']

epochs = range(len(gender_train_loss))


# Gender Loss
plt.subplot(2, 2, 1)
plt.plot(epochs, gender_train_loss, label='Train Loss')
plt.plot(epochs, gender_val_loss, label='Validation Loss')
plt.title('Gender Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gender Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, gender_train_accuracy, label='Train Accuracy')
plt.plot(epochs, gender_val_accuracy, label='Validation Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Age Loss
plt.subplot(2, 2, 3)
plt.plot(epochs, age_train_loss, label='Train Loss')
plt.plot(epochs, age_val_loss, label='Validation Loss')
plt.title('Age Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Age MAE
plt.subplot(2, 2, 4)
plt.plot(epochs, age_train_accuracy, label='Train MAE')
plt.plot(epochs, age_val_accuracy, label='Validation MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
