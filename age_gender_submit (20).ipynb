# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow

dataset_path = "/content/drive/MyDrive/train_val" #for google colab
#dataset_path = "train_val" #for local running

image_files = [f for f in os.listdir(dataset_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

random.shuffle(image_files)
selected_images = image_files[:20]

def extract_label(filename):
    try:
        name = filename.split('_')
        age = int(name[0])
        gender = "Male" if name[1] == "0" else "Female"  # Second part is gender (0 = Male, 1 = Female)
        return age, gender
    except:
        return None, None  # Handle unexpected filename formats

# Plot 20 images in a 4x5 grid
fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for i, ax in enumerate(axes.flat):
    if i < len(selected_images):
        img_path = os.path.join(dataset_path, selected_images[i])
        img = cv2.imread(img_path)  # Read image
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

        # Extract labels from filename
        age, gender = extract_label(selected_images[i])
        label = f"Age: {age}, Gender: {gender}" if age is not None else "Unknown"

        # Display image
        ax.imshow(img)
        ax.set_title(label, fontsize=10)
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
folder_train_val = "/content/drive/MyDrive/train_val" #for google colab
#folder_train_val = "train_val" #for local running

all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
    print('load all image data, age and gender labels...')
    images = []
    age_labels = []
    gender_labels = []
    for current_file_name in filenames:
        img = cv2.imread(os.path.join(dataset_path, current_file_name))
        img = img / 255.0  # Normalize pixel values
        labels = current_file_name.split('_')
        age_label = int(labels[0])
        gender_label = int(labels[1])
        age_labels.append(age_label)
        gender_labels.append(gender_label)
        images.append(img)

# Convert to NumPy arrays
    images = np.array(images)
    age_labels = np.array(age_labels)
    gender_labels = np.array(gender_labels)
    return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
######### Add your code for data augmentation here #########
#
inputs = tensorflow.keras.Input(shape=(128, 128, 3))
# Apply data augmentation layers to the inputs
augmented = tensorflow.keras.layers.RandomFlip("horizontal")(inputs)
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
x = tensorflow.keras.layers.Conv2D(32, (3, 3), activation='relu')(augmented)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(128, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Conv2D(256, (3, 3), activation='relu')(x)
x = tensorflow.keras.layers.MaxPooling2D(2, 2)(x)

x = tensorflow.keras.layers.Flatten()(x)
x = tensorflow.keras.layers.Dense(256, activation='relu')(x)
x = tensorflow.keras.layers.Dropout(0.3)(x)

gender = tensorflow.keras.layers.Dense(1, activation='sigmoid', name='gender')(x)
age = tensorflow.keras.layers.Dense(1, activation='linear', name='age')(x)

modelA = tensorflow.keras.Model(inputs=inputs, outputs=[gender, age])

modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True,dpi=100)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_flip (RandomFlip)  │ (None, 128, 128, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 126, 126, 32)   │            896 │ random_flip[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 63, 63, 32)     │              0 │ conv2d[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 61, 61, 64)     │         18,496 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 30, 30, 64)     │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 28, 28, 128)    │         73,856 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 14, 14, 128)    │              0 │ conv2d_2[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 12, 12, 256)    │        295,168 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 6, 6, 256)      │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 9216)           │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │      2,359,552 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 256)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │            257 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            257 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,748,482 (10.48 MB)
#  Trainable params: 2,748,482 (10.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_gender_accuracy',patience=5,restore_best_weights=True,mode='max',verbose=1)

modelA.compile(
    optimizer=tensorflow.keras.optimizers.Adam(),
    loss={
        "gender": tensorflow.keras.losses.BinaryCrossentropy(),
        "age": tensorflow.keras.losses.MeanAbsoluteError(),
    },
    loss_weights = {"gender": 1.5, "age": 1.0},
    metrics={
        "gender": ["accuracy"],
        "age": ["mae"]
    }
)

historyA = modelA.fit(
    x=train_images,
    y={
        "gender": train_gender,
        "age": train_age
    },
    validation_data=(
        val_images,
        {
            "gender": val_gender,
            "age": val_age
        }
    ),
    epochs=30 ,
    batch_size=32,
    callbacks=[early_stopping]
)

import os

folder_models = "/content/drive/MyDrive/models/temp/"
if not os.path.exists(folder_models):
    os.makedirs(folder_models)

# Save the model only once using the correct absolute path
modelA.save(os.path.join(folder_models, 'age_gender_A.keras'))
print("Model saved successfully!")
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - age_loss: 18.7613 - age_mae: 18.7613 - gender_accuracy: 0.5170 - gender_loss: 1.1119 - loss: 20.4292 - val_age_loss: 15.3054 - val_age_mae: 15.3275 - val_gender_accuracy: 0.5860 - val_gender_loss: 0.6854 - val_loss: 16.3550
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 14.9120 - age_mae: 14.9120 - gender_accuracy: 0.5182 - gender_loss: 0.8100 - loss: 16.1271 - val_age_loss: 14.8096 - val_age_mae: 14.8124 - val_gender_accuracy: 0.5540 - val_gender_loss: 0.6684 - val_loss: 15.8160
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 14.5171 - age_mae: 14.5171 - gender_accuracy: 0.5386 - gender_loss: 0.7442 - loss: 15.6334 - val_age_loss: 13.2459 - val_age_mae: 13.2793 - val_gender_accuracy: 0.6800 - val_gender_loss: 0.5937 - val_loss: 14.1545
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - age_loss: 12.4542 - age_mae: 12.4542 - gender_accuracy: 0.6770 - gender_loss: 0.6483 - loss: 13.4266 - val_age_loss: 11.8267 - val_age_mae: 11.8631 - val_gender_accuracy: 0.7080 - val_gender_loss: 0.5561 - val_loss: 12.6864
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 11.7008 - age_mae: 11.7008 - gender_accuracy: 0.6979 - gender_loss: 0.5851 - loss: 12.5785 - val_age_loss: 11.9884 - val_age_mae: 12.0075 - val_gender_accuracy: 0.7620 - val_gender_loss: 0.5174 - val_loss: 12.7826
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 11.1943 - age_mae: 11.1943 - gender_accuracy: 0.7169 - gender_loss: 0.5548 - loss: 12.0266 - val_age_loss: 10.6927 - val_age_mae: 10.7184 - val_gender_accuracy: 0.7650 - val_gender_loss: 0.4886 - val_loss: 11.4412
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - age_loss: 10.8283 - age_mae: 10.8283 - gender_accuracy: 0.7449 - gender_loss: 0.5227 - loss: 11.6123 - val_age_loss: 9.9077 - val_age_mae: 9.9145 - val_gender_accuracy: 0.7660 - val_gender_loss: 0.4666 - val_loss: 10.6021
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 10.0954 - age_mae: 10.0954 - gender_accuracy: 0.7544 - gender_loss: 0.4995 - loss: 10.8447 - val_age_loss: 9.6601 - val_age_mae: 9.6644 - val_gender_accuracy: 0.8000 - val_gender_loss: 0.4413 - val_loss: 10.3216
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 9.8154 - age_mae: 9.8154 - gender_accuracy: 0.7555 - gender_loss: 0.5001 - loss: 10.5655 - val_age_loss: 9.2649 - val_age_mae: 9.2355 - val_gender_accuracy: 0.8020 - val_gender_loss: 0.4267 - val_loss: 9.8703
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - age_loss: 9.2668 - age_mae: 9.2668 - gender_accuracy: 0.7789 - gender_loss: 0.4678 - loss: 9.9685 - val_age_loss: 9.4856 - val_age_mae: 9.4944 - val_gender_accuracy: 0.7970 - val_gender_loss: 0.4136 - val_loss: 10.1117
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 9.4380 - age_mae: 9.4380 - gender_accuracy: 0.7843 - gender_loss: 0.4586 - loss: 10.1259 - val_age_loss: 9.0163 - val_age_mae: 9.0391 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.3987 - val_loss: 9.6335
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 8.7305 - age_mae: 8.7305 - gender_accuracy: 0.7906 - gender_loss: 0.4435 - loss: 9.3958 - val_age_loss: 8.5003 - val_age_mae: 8.5210 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.3837 - val_loss: 9.0919
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 8.3826 - age_mae: 8.3826 - gender_accuracy: 0.8043 - gender_loss: 0.4093 - loss: 8.9966 - val_age_loss: 8.3162 - val_age_mae: 8.3579 - val_gender_accuracy: 0.8300 - val_gender_loss: 0.3767 - val_loss: 8.9182
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 8.7290 - age_mae: 8.7290 - gender_accuracy: 0.8002 - gender_loss: 0.4182 - loss: 9.3563 - val_age_loss: 9.1428 - val_age_mae: 9.1209 - val_gender_accuracy: 0.8210 - val_gender_loss: 0.4047 - val_loss: 9.7179
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 8.3351 - age_mae: 8.3351 - gender_accuracy: 0.8266 - gender_loss: 0.4026 - loss: 8.9390 - val_age_loss: 8.1550 - val_age_mae: 8.1266 - val_gender_accuracy: 0.8460 - val_gender_loss: 0.3520 - val_loss: 8.6470
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - age_loss: 7.6317 - age_mae: 7.6317 - gender_accuracy: 0.8373 - gender_loss: 0.3772 - loss: 8.1975 - val_age_loss: 7.9707 - val_age_mae: 7.9087 - val_gender_accuracy: 0.8380 - val_gender_loss: 0.3535 - val_loss: 8.4320
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 7.4589 - age_mae: 7.4589 - gender_accuracy: 0.8239 - gender_loss: 0.3856 - loss: 8.0373 - val_age_loss: 8.0902 - val_age_mae: 8.0937 - val_gender_accuracy: 0.8250 - val_gender_loss: 0.3578 - val_loss: 8.6236
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - age_loss: 7.4705 - age_mae: 7.4705 - gender_accuracy: 0.8417 - gender_loss: 0.3545 - loss: 8.0022 - val_age_loss: 8.3054 - val_age_mae: 8.3021 - val_gender_accuracy: 0.8270 - val_gender_loss: 0.3757 - val_loss: 8.8507
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 7.4397 - age_mae: 7.4397 - gender_accuracy: 0.8432 - gender_loss: 0.3576 - loss: 7.9761 - val_age_loss: 8.3450 - val_age_mae: 8.3803 - val_gender_accuracy: 0.8600 - val_gender_loss: 0.3197 - val_loss: 8.8578
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 6.9106 - age_mae: 6.9106 - gender_accuracy: 0.8398 - gender_loss: 0.3555 - loss: 7.4438 - val_age_loss: 7.4981 - val_age_mae: 7.4922 - val_gender_accuracy: 0.8460 - val_gender_loss: 0.3453 - val_loss: 8.0042
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 6.6858 - age_mae: 6.6858 - gender_accuracy: 0.8501 - gender_loss: 0.3351 - loss: 7.1883 - val_age_loss: 7.6602 - val_age_mae: 7.6041 - val_gender_accuracy: 0.8580 - val_gender_loss: 0.3220 - val_loss: 8.0817
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 6.7603 - age_mae: 6.7603 - gender_accuracy: 0.8607 - gender_loss: 0.3189 - loss: 7.2386 - val_age_loss: 7.5113 - val_age_mae: 7.5138 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.3896 - val_loss: 8.0828
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 6.4134 - age_mae: 6.4134 - gender_accuracy: 0.8640 - gender_loss: 0.3290 - loss: 6.9070 - val_age_loss: 7.6624 - val_age_mae: 7.7049 - val_gender_accuracy: 0.8640 - val_gender_loss: 0.2986 - val_loss: 8.1462
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 6.2978 - age_mae: 6.2978 - gender_accuracy: 0.8625 - gender_loss: 0.3209 - loss: 6.7792 - val_age_loss: 7.6093 - val_age_mae: 7.5944 - val_gender_accuracy: 0.8660 - val_gender_loss: 0.3084 - val_loss: 8.0458
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - age_loss: 6.3757 - age_mae: 6.3757 - gender_accuracy: 0.8781 - gender_loss: 0.2853 - loss: 6.8036 - val_age_loss: 8.7618 - val_age_mae: 8.7752 - val_gender_accuracy: 0.8600 - val_gender_loss: 0.3471 - val_loss: 9.2862
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - age_loss: 6.1754 - age_mae: 6.1754 - gender_accuracy: 0.8705 - gender_loss: 0.2893 - loss: 6.6094 - val_age_loss: 7.8208 - val_age_mae: 7.8096 - val_gender_accuracy: 0.8580 - val_gender_loss: 0.3248 - val_loss: 8.2760
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 6.1222 - age_mae: 6.1222 - gender_accuracy: 0.8696 - gender_loss: 0.3029 - loss: 6.5766 - val_age_loss: 7.4429 - val_age_mae: 7.4626 - val_gender_accuracy: 0.8610 - val_gender_loss: 0.3005 - val_loss: 7.9016
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - age_loss: 5.5832 - age_mae: 5.5832 - gender_accuracy: 0.8841 - gender_loss: 0.2813 - loss: 6.0051 - val_age_loss: 7.5529 - val_age_mae: 7.5473 - val_gender_accuracy: 0.8650 - val_gender_loss: 0.3006 - val_loss: 7.9929
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 5.7637 - age_mae: 5.7637 - gender_accuracy: 0.8617 - gender_loss: 0.3033 - loss: 6.2186 - val_age_loss: 7.4765 - val_age_mae: 7.4814 - val_gender_accuracy: 0.8600 - val_gender_loss: 0.3403 - val_loss: 7.9705
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Model saved successfully!

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
import matplotlib.pyplot as plt

gender_train_loss = historyA.history['gender_loss']
gender_val_loss = historyA.history['val_gender_loss']

gender_train_accuracy = historyA.history['gender_accuracy']
gender_val_accuracy = historyA.history['val_gender_accuracy']

age_train_loss = historyA.history['age_loss']
age_val_loss = historyA.history['val_age_loss']

age_train_accuracy = historyA.history['age_mae']
age_val_accuracy = historyA.history['val_age_mae']

epochs = range(len(gender_train_loss))

plt.figure(figsize=(12, 10))  # Increase figure size for better spacing

# Adjust subplot spacing
plt.subplots_adjust(hspace=0.4, wspace=0.3)  # hspace controls vertical spacing, wspace controls horizontal spacing

# Gender Loss
plt.subplot(2, 2, 1)
plt.plot(epochs, gender_train_loss, label='Train Loss')
plt.plot(epochs, gender_val_loss, label='Validation Loss')
plt.title('Gender Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gender Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, gender_train_accuracy, label='Train Accuracy')
plt.plot(epochs, gender_val_accuracy, label='Validation Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Age Loss
plt.subplot(2, 2, 3)
plt.plot(epochs, age_train_loss, label='Train Loss')
plt.plot(epochs, age_val_loss, label='Validation Loss')
plt.title('Age Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Age MAE
plt.subplot(2, 2, 4)
plt.plot(epochs, age_train_accuracy, label='Train MAE')
plt.plot(epochs, age_val_accuracy, label='Validation MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# MobileNetV2 with our specified input shape
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(128, 128, 3))


base_model.trainable = False


x = base_model(augmented)
x = GlobalAveragePooling2D()(x)

x = Dense(128, activation="relu")(x)
x = Dropout(0.3)(x)

#creating the branches for both estimaters
age_output = Dense(1, activation="linear", name="age")(x)
gender_output = Dense(1, activation="sigmoid", name="gender")(x) # Same activation functions as before



modelB = Model(inputs=inputs, outputs=[age_output, gender_output])

modelB.summary()
plot_model(modelB, to_file="modelB_architecture.png", show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_flip (RandomFlip)  │ (None, 128, 128, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mobilenetv2_1.00_128      │ (None, 4, 4, 1280)     │      2,257,984 │ random_flip[0][0]      │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ mobilenetv2_1.00_128[… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age (Dense)               │ (None, 1)              │            129 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender (Dense)            │ (None, 1)              │            129 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,210 (9.24 MB)
#  Trainable params: 164,226 (641.51 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
import tensorflow as tf
import os
from tensorflow.keras.callbacks import EarlyStopping

# same compilation structure as before
modelB.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss={"age": "mean_absolute_error", "gender": "binary_crossentropy"},
    metrics={"age": "mae", "gender": "accuracy"}
)

early_stopping = EarlyStopping(monitor='val_gender_accuracy',patience=8,restore_best_weights=True,mode='max',verbose=1)

# Training, keeping the parameters the same as previous
historyB = modelB.fit(
    x=train_images,
    y={"age": train_age, "gender": train_gender},
    validation_data=(val_images, {"age": val_age, "gender": val_gender}),
    epochs=30,
    batch_size=32,
    callbacks=[early_stopping]
)

import os

folder_models = "/content/drive/MyDrive/models/temp/"
if not os.path.exists(folder_models):
    os.makedirs(folder_models)

# Save the model only once using the correct absolute path
modelB.save(os.path.join(folder_models, 'age_gender_B.keras'))
print("Model saved successfully!")
# Out:
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - age_loss: 15.8039 - age_mae: 15.8039 - gender_accuracy: 0.6236 - gender_loss: 0.9729 - loss: 16.7769 - val_age_loss: 10.5052 - val_age_mae: 10.4719 - val_gender_accuracy: 0.7970 - val_gender_loss: 0.4588 - val_loss: 10.9257
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - age_loss: 10.6527 - age_mae: 10.6527 - gender_accuracy: 0.7228 - gender_loss: 0.6476 - loss: 11.3004 - val_age_loss: 10.5641 - val_age_mae: 10.5710 - val_gender_accuracy: 0.7820 - val_gender_loss: 0.4832 - val_loss: 11.0518
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 9.6868 - age_mae: 9.6868 - gender_accuracy: 0.7654 - gender_loss: 0.5497 - loss: 10.2365 - val_age_loss: 9.9891 - val_age_mae: 9.9798 - val_gender_accuracy: 0.8200 - val_gender_loss: 0.4288 - val_loss: 10.3982
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - age_loss: 9.8792 - age_mae: 9.8792 - gender_accuracy: 0.7706 - gender_loss: 0.4999 - loss: 10.3791 - val_age_loss: 9.5709 - val_age_mae: 9.5310 - val_gender_accuracy: 0.8220 - val_gender_loss: 0.4090 - val_loss: 9.9324
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - age_loss: 9.3885 - age_mae: 9.3885 - gender_accuracy: 0.7875 - gender_loss: 0.4551 - loss: 9.8436 - val_age_loss: 9.3611 - val_age_mae: 9.3437 - val_gender_accuracy: 0.8260 - val_gender_loss: 0.4150 - val_loss: 9.7463
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - age_loss: 9.0995 - age_mae: 9.0995 - gender_accuracy: 0.8046 - gender_loss: 0.4431 - loss: 9.5425 - val_age_loss: 9.1925 - val_age_mae: 9.1792 - val_gender_accuracy: 0.8270 - val_gender_loss: 0.3907 - val_loss: 9.5623
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 9.1424 - age_mae: 9.1424 - gender_accuracy: 0.8057 - gender_loss: 0.4290 - loss: 9.5714 - val_age_loss: 9.0119 - val_age_mae: 8.9809 - val_gender_accuracy: 0.8250 - val_gender_loss: 0.3979 - val_loss: 9.3695
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - age_loss: 8.8423 - age_mae: 8.8423 - gender_accuracy: 0.8132 - gender_loss: 0.4099 - loss: 9.2522 - val_age_loss: 8.9763 - val_age_mae: 8.9638 - val_gender_accuracy: 0.8350 - val_gender_loss: 0.3878 - val_loss: 9.3448
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 8.8153 - age_mae: 8.8153 - gender_accuracy: 0.8089 - gender_loss: 0.4111 - loss: 9.2264 - val_age_loss: 8.9211 - val_age_mae: 8.9150 - val_gender_accuracy: 0.8330 - val_gender_loss: 0.3862 - val_loss: 9.2951
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - age_loss: 8.5912 - age_mae: 8.5912 - gender_accuracy: 0.8165 - gender_loss: 0.4004 - loss: 8.9916 - val_age_loss: 8.9726 - val_age_mae: 8.9414 - val_gender_accuracy: 0.8330 - val_gender_loss: 0.3984 - val_loss: 9.3271
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - age_loss: 8.7380 - age_mae: 8.7380 - gender_accuracy: 0.8229 - gender_loss: 0.3992 - loss: 9.1372 - val_age_loss: 9.0041 - val_age_mae: 9.0025 - val_gender_accuracy: 0.8360 - val_gender_loss: 0.3869 - val_loss: 9.3824
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - age_loss: 8.5881 - age_mae: 8.5881 - gender_accuracy: 0.8249 - gender_loss: 0.3787 - loss: 8.9668 - val_age_loss: 8.8289 - val_age_mae: 8.8204 - val_gender_accuracy: 0.8340 - val_gender_loss: 0.3985 - val_loss: 9.2074
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - age_loss: 8.2418 - age_mae: 8.2418 - gender_accuracy: 0.8337 - gender_loss: 0.3793 - loss: 8.6211 - val_age_loss: 8.8483 - val_age_mae: 8.8510 - val_gender_accuracy: 0.8400 - val_gender_loss: 0.3799 - val_loss: 9.2225
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - age_loss: 8.2329 - age_mae: 8.2329 - gender_accuracy: 0.8334 - gender_loss: 0.3802 - loss: 8.6131 - val_age_loss: 8.8833 - val_age_mae: 8.8840 - val_gender_accuracy: 0.8370 - val_gender_loss: 0.3845 - val_loss: 9.2582
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - age_loss: 8.3036 - age_mae: 8.3036 - gender_accuracy: 0.8327 - gender_loss: 0.3706 - loss: 8.6742 - val_age_loss: 9.2196 - val_age_mae: 9.2203 - val_gender_accuracy: 0.8360 - val_gender_loss: 0.3856 - val_loss: 9.5994
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - age_loss: 8.2215 - age_mae: 8.2215 - gender_accuracy: 0.8334 - gender_loss: 0.3696 - loss: 8.5911 - val_age_loss: 8.7533 - val_age_mae: 8.7423 - val_gender_accuracy: 0.8230 - val_gender_loss: 0.3962 - val_loss: 9.1350
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - age_loss: 8.0097 - age_mae: 8.0097 - gender_accuracy: 0.8379 - gender_loss: 0.3616 - loss: 8.3714 - val_age_loss: 8.8759 - val_age_mae: 8.8924 - val_gender_accuracy: 0.8370 - val_gender_loss: 0.3958 - val_loss: 9.2767
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - age_loss: 7.9868 - age_mae: 7.9868 - gender_accuracy: 0.8396 - gender_loss: 0.3721 - loss: 8.3589 - val_age_loss: 9.0697 - val_age_mae: 9.0731 - val_gender_accuracy: 0.8310 - val_gender_loss: 0.4242 - val_loss: 9.4777
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - age_loss: 8.0761 - age_mae: 8.0761 - gender_accuracy: 0.8213 - gender_loss: 0.3835 - loss: 8.4596 - val_age_loss: 8.6669 - val_age_mae: 8.6603 - val_gender_accuracy: 0.8340 - val_gender_loss: 0.3852 - val_loss: 9.0369
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - age_loss: 7.8137 - age_mae: 7.8137 - gender_accuracy: 0.8368 - gender_loss: 0.3508 - loss: 8.1645 - val_age_loss: 8.9734 - val_age_mae: 8.9727 - val_gender_accuracy: 0.8040 - val_gender_loss: 0.4678 - val_loss: 9.4236
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - age_loss: 7.9783 - age_mae: 7.9783 - gender_accuracy: 0.8377 - gender_loss: 0.3609 - loss: 8.3393 - val_age_loss: 8.6397 - val_age_mae: 8.6487 - val_gender_accuracy: 0.8310 - val_gender_loss: 0.3872 - val_loss: 9.0243
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Model saved successfully!

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
import matplotlib.pyplot as plt

gender_train_loss = historyB.history['gender_loss']
gender_val_loss = historyB.history['val_gender_loss']

gender_train_accuracy = historyB.history['gender_accuracy']
gender_val_accuracy = historyB.history['val_gender_accuracy']

age_train_loss = historyB.history['age_loss']
age_val_loss = historyB.history['val_age_loss']

age_train_accuracy = historyB.history['age_mae']
age_val_accuracy = historyB.history['val_age_mae']

epochs = range(len(gender_train_loss))

plt.figure(figsize=(12, 10))  # Increase figure size for better spacing

# Adjust subplot spacing
plt.subplots_adjust(hspace=0.4, wspace=0.3)  # hspace for vertical spacing, wspace for horizontal spacing

# Gender Loss
plt.subplot(2, 2, 1)
plt.plot(epochs, gender_train_loss, label='Train Loss')
plt.plot(epochs, gender_val_loss, label='Validation Loss')
plt.title('Gender Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gender Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, gender_train_accuracy, label='Train Accuracy')
plt.plot(epochs, gender_val_accuracy, label='Validation Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Age Loss
plt.subplot(2, 2, 3)
plt.plot(epochs, age_train_loss, label='Train Loss')
plt.plot(epochs, age_val_loss, label='Validation Loss')
plt.title('Age Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Age MAE
plt.subplot(2, 2, 4)
plt.plot(epochs, age_train_accuracy, label='Train MAE')
plt.plot(epochs, age_val_accuracy, label='Validation MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
